# %% [markdown]
# ### This is a demo script of python notebook

# %%
import numpy as np
from matplotlib import pyplot as plt

# %% [markdown]
# ### make a random array and print it

# %% [markdown]
# Enter the number of random points you wish to plot below

# %%
i = 50

# %%
print(i)
x = np.random.rand(1,int(i))
y = np.random.rand(1,int(i))
plt.plot(x,y, "-o")
plt.show
# Out:
# 50
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
x = [0.25*i for i in range(0,26)]
y = [np.sin(i) for i in x] 
z = [np.cos(i) for i in x]

# %%
plt.plot(x,y, "-o")
plt.plot(x,z, "-o")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
